# %% [markdown]
# <a href="https://colab.research.google.com/github/lokesh31333/Python/blob/master/Z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

import numpy as np

# %%
excel_file = 'z.xlsx'
tocode = pd.read_excel(excel_file)
# opening Excel File

# %%
tocode
# Out:
#    SaaS_ID  ...  Service Completion Time for Service - B
# 0      SP1  ...                                 1.947587
# 1      SP2  ...                                 1.974140
# 2      SP3  ...                                 1.644647
# 3      SP4  ...                                 2.069013
# 4      SP5  ...                                 1.767420
# 5      SP6  ...                                 2.028807
# 6      SP7  ...                                 2.242067
# 7      SP8  ...                                 1.803287
# 8      SP9  ...                                 2.210567
# 9     SP10  ...                                 1.855427
# 10    SP11  ...                                 2.103440
# 11    SP12  ...                                 1.889047
# 12    SP13  ...                                 1.732653
# 13    SP14  ...                                 1.822047
# 14    SP15  ...                                 1.996613
# ...

# %%
tocode["Total Service Accesible Time"] = (tocode["Service Accessible time for Service A"] + tocode["Service Accessible time for Service B"] )


# Calculating the Total Service Accesible Time

# %%
tocode["Total Service Completion time"] = (tocode["Service Completion Time for Service - A"] + tocode["Service Completion Time for Service - B"])

# %%
tocode["AVG No. of Services by the provider"] = tocode["Total Service Completion time"]/tocode["Total Service Accesible Time"]

# %%
tocode["Utilization(%) of services to customer"] = (1/tocode["AVG No. of Services by the provider"])*100

# %%
Final_Table = tocode[["SaaS_ID","Service Accessible time for Service A","Service Accessible time for Service B","Total Service Accesible Time","Service Completion Time for Service - A","Service Completion Time for Service - B","Total Service Completion time","AVG No. of Services by the provider","Utilization(%) of services to customer"]]
Final_Table
# Out:
#    SaaS_ID  ...  Utilization(%) of services to customer
# 0      SP1  ...                               20.538239
# 1      SP2  ...                                6.753996
# 2      SP3  ...                               12.160667
# 3      SP4  ...                                9.666443
# 4      SP5  ...                               15.087906
# 5      SP6  ...                               19.716024
# 6      SP7  ...                               20.814130
# 7      SP8  ...                                7.393907
# 8      SP9  ...                               21.110726
# 9     SP10  ...                               10.779192
# 10    SP11  ...                               22.185880
# 11    SP12  ...                               24.703819
# 12    SP13  ...                               11.542990
# 13    SP14  ...                               18.294445
# 14    SP15  ...                               16.694937
# 15    SP16  ...                               10.896372
# ...

# %%
barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Total Service Accesible Time"]



X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
   
# Make the plot 

plt.bar(br2, toplot, color ='#99a9de', width = barWidth, 
        edgecolor ='black', label ='Total Service Accesible Time') 

plt.title("Total Service Accesible Time of Services")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,0.8])
 
plt.yticks(np.arange(0,0.8, 0.1))

plt.legend()
plt.show()

# %%
#Total Service Completion time of Services

barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Total Service Completion time"] 


X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
   
# Make the plot 

plt.bar(br2, toplot, color ='#99a9de', width = barWidth, 
        edgecolor ='black', label ='Total Service Completion Time') 

plt.title("Total Service Completion Time of Services")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,3.5])
 
plt.yticks(np.arange(0,3.5, 0.5))

plt.legend()
plt.show()

# %%
#Providers Services Access time at an Instance
#Service Providers Services and its Utilization %
#Utilization(%) of Services by Consumer
#Total Service Completion time of Services

barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Service Accessible time for Service A"] 

toplot2 = tocode["Service Accessible time for Service B"]
X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
   
# Make the plot 

plt.bar(br2, toplot, color ='#99a9de', width = barWidth, 
        edgecolor ='black', label ='Service Accessible time for Service A') 
plt.bar(br3, toplot2, color ='#A52A2A', width = barWidth, 
        edgecolor ='grey', label ='Service Accessible time for Service B') 

plt.title("Providers Services Access time at an Instance%")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,0.8])
 
plt.yticks(np.arange(0,0.8,0.1))

plt.legend()
plt.show()

# %%
#Providers Services Completion time at an Instance
#Providers Services Access time at an Instance
#Service Providers Services and its Utilization %
#Utilization(%) of Services by Consumer
#Total Service Completion time of Services

barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Service Completion Time for Service - A"] 

toplot2 = tocode["Service Completion Time for Service - B"]
X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
   
# Make the plot 

plt.bar(br2, toplot, color ='#99a9de', width = barWidth, 
        edgecolor ='black', label ='Service Completion time for Service A') 
plt.bar(br3, toplot2, color ='#A52A2A', width = barWidth, 
        edgecolor ='grey', label ='Service Completion time for Service B') 

plt.title("Providers Services Completion time at an Instance%")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,2.5])
 
plt.yticks(np.arange(0,2.5,0.5))

plt.legend()
plt.show()

# %%
#Utilization(%) of Services by Consumer
#Total Service Completion time of Services

barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Utilization(%) of services to customer"] 


X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
   
# Make the plot 

plt.bar(br2, toplot, color ='#99a9de', width = barWidth, 
        edgecolor ='black', label ='Utilization(%) of Services by Consumer') 

plt.title("Utilization(%) of Services by Consumer")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,30])
 
plt.yticks(np.arange(0,30, 5))

plt.legend()
plt.show()

# %%
#Service Providers Services and its Utilization %
#Utilization(%) of Services by Consumer
#Total Service Completion time of Services

barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Utilization(%) of services to customer"] 

toplot2 = tocode["AVG No. of Services by the provider"]
X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
   
# Make the plot 

plt.bar(br2, toplot, color ='#99a9de', width = barWidth, 
        edgecolor ='black', label ='Utilization(%) of Services by Consumer') 
plt.bar(br3, toplot2, color ='#A52A2A', width = barWidth, 
        edgecolor ='grey', label ='AVG No. of Services by the provider') 

plt.title("Service Providers Services and its Utilization %")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,30])
 
plt.yticks(np.arange(0,30, 5))

plt.legend()
plt.show()

# %%
#Service Providers Services and its Utilization %
#Utilization(%) of Services by Consumer
#Total Service Completion time of Services

barWidth = 0.5
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
toplot = tocode["Utilization(%) of services to customer"] 

toplot2 = tocode["Total Service Accesible Time"]
toplot3 = tocode["Total Service Completion time"]
X = np.arange(len(tocode["SaaS_ID"]))

   
# Set position of bar on X axis 
br1 = np.arange(len(toplot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
br4 = [x + barWidth for x in br1]  
# Make the plot 

plt.bar(br2, toplot, color ='green', width = barWidth, 
        edgecolor ='black', label ='Utilization(%) of Services by Consumer') 
plt.bar(br3, toplot2, color ='blue', width = barWidth, 
        edgecolor ='grey', label ='Total Service Accesible Time')
plt.bar(br4, toplot3, color ='red', width = barWidth, 
        edgecolor ='grey', label ='Total Service Completion time')  

plt.title("Results")
# Adding Xticks  
plt.xlabel('', fontweight ='bold') 
plt.ylabel('', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(toplot))], 
           tocode["SaaS_ID"])
plt.ylim([0,30])
 
plt.yticks(np.arange(0,30, 5))

plt.legend()
plt.show()
